# %%
A = [1, 2, 3]

print(A)
# Out:
# [1, 2, 3]

# %%
# Append - Insert element at the end of array - On average: O(1)
A.append(5)

print(A)
# Out:
# [1, 2, 3, 5]

# %%
# Pop - Deleting element at end of array - 0(1)
A.pop()

print(A)
# Out:
# [1, 2, 3]

# %%
# Insert (not at end of array) - O(n)
A.insert(2,5)

print(A)
# Out:
# [1, 2, 5, 3]

# %%
# Modify an element - O(1)
A[0] = 7

print(A)
# Out:
# [7, 2, 5, 3]

# %%
# Accessing element given index 1 - O(1)
print(A[2])
# Out:
# 5

# %%
# Checking if array has an element - O(n)
if 7 in A:
  print(True)
# Out:
# True

# %%
# Checking length - O(1)
print(len(A))
# Out:
# 4

# %%
# Strings

# %%
# Append to end of string - O(n)
s = 'hello'

b = s + 'z'

print(b)
# Out:
# helloz

# %%
# Check if something is in string - O(n)
if 'f' in s:
  print(True)

# %%
# Access positions - O(1)
print(s[2])
# Out:
# l

# %%
# Check length of string - O(1)
len(s)
# Out:
# 5
