# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/data-structures-and-algorithms-python/blob/main/Array_easy_Largest_Element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Given an array of integers nums, return the value of the largest element in the array


# Example 1

# Input: nums = [3, 3, 6, 1]

# Output: 6

# Explanation: The largest element in array is 6

# Example 2

# Input: nums = [3, 3, 0, 99, -40]

# Output: 99

# Explanation: The largest element in array is 99

# %%
nums = [3,3,6,1]

class Solution:
  def LargestElement(self, nums):
    return max(nums)

# create object of class
sol = Solution()

# call the function and print the result
print(sol.LargestElement(nums))
# Out:
# 6
